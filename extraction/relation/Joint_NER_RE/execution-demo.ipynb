# %%
from google.colab import drive
drive.mount('/content/drive/')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3Aietf%3Awg%3Aoauth%3A2.0%3Aoob&scope=email%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdocs.test%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive.photos.readonly%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fpeopleapi.readonly&response_type=code
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive/

# %%
# %cd '/content/drive/My Drive/Project_Relation_Extraction'
# Out:
# /content/drive/My Drive/Project_Relation_Extraction

# %%
# !git clone https://github.com/bekou/multihead_joint_entity_relation_extraction.git
# Out:
# Cloning into 'multihead_joint_entity_relation_extraction'...
# remote: Enumerating objects: 21, done.
# remote: Counting objects: 100% (21/21), done.
# remote: Compressing objects: 100% (14/14), done.
# remote: Total 155 (delta 7), reused 21 (delta 7), pack-reused 134
# Receiving objects: 100% (155/155), 171.31 MiB | 19.78 MiB/s, done.
# Resolving deltas: 100% (75/75), done.
# Checking out files: 100% (23/23), done.

# %%
cd multihead_joint_entity_relation_extraction
# Out:
# /content/drive/My Drive/Project_Relation_Extraction/multihead_joint_entity_relation_extraction

# %%
# %%shell
#
# timestamp=`date "+%d.%m.%Y_%H.%M.%S"`
# output_dir='./logs/'
# config_file='./configs/CoNLL04/bio_config'
#
# unzip data/CoNLL04/vecs.lc.over100freq.zip -d data/CoNLL04/
#
# mkdir -p $output_dir
#
#
#
#
# python3 -u train_es.py ${config_file} ${timestamp} ${output_dir} 2>&1 | tee ${output_dir}log.dev_${timestamp}.txt
#
# python3 -u train_eval.py ${config_file} ${timestamp} ${output_dir} 2>&1 | tee ${output_dir}log.test.${timestamp}.txt
# Out:
# Archive:  data/CoNLL04/vecs.lc.over100freq.zip
#   inflating: data/CoNLL04/vecs.lc.over100freq.txt
# /usr/local/lib/python3.6/dist-packages/smart_open/ssh.py:34: UserWarning: paramiko missing, opening SSH/SCP/SFTP paths will be disabled.  `pip install paramiko` to suppress
#   warnings.warn('paramiko missing, opening SSH/SCP/SFTP paths will be disabled.  `pip install paramiko` to suppress')
# /content/drive/My Drive/Project_Relation_Extraction/multihead_joint_entity_relation_extraction/parsers.py:68: FutureWarning: Method .as_matrix will be removed in a future version. Use .values instead.
#   engine='python', sep="\t", quoting=csv.QUOTE_NONE).as_matrix()
# +------------------------+--------------------------------------+
# |         Params         |                Value                 |
# +------------------------+--------------------------------------+
# |         Config         |     ./configs/CoNLL04/bio_config     |
# |       Embeddings       | data/CoNLL04/vecs.lc.over100freq.txt |
# |    Embeddings size     |                  50                  |
# |         Train          |        data/CoNLL04/train.txt        |
# |          Dev           |         data/CoNLL04/dev.txt         |
# |          Test          |        data/CoNLL04/test.txt         |
# |        Epochs          |                 150                  |
# |       Optimizer        |                 Adam                 |
# |      Activation        |                 tanh                 |
# |     Learning rate      |                0.001                 |
# |   Gradient clipping    |                False                 |
# |       Patience         |                  30                  |
# |      Use dropout       |                 True                 |
# |       Ner loss         |                 crf                  |
# |      Ner classes       |                 BIO                  |
# |  Use char embeddings   |                 True                 |
# |    Use adversarial     |                False                 |
# |   Dropout embedding    |                 0.9                  |
# |     Dropout lstm       |                 0.9                  |
# |  Dropout lstm output   |                 0.9                  |
# |    Dropout fcl ner     |                 1.0                  |
# |    Dropout fcl rel     |                 1.0                  |
# |   Hidden lstm size     |                  64                  |
# |      LSTM layers       |                  3                   |
# |    Hidden nn size      |                  64                  |
# | Char embeddings size   |                  25                  |
# |   Hidden size char     |                  25                  |
# | Label embeddings size  |                  0                   |
# |         Alpha          |                 0.01                 |
# |       Root node        |                False                 |
# |   Evaluation method    |                strict                |
# +------------------------+--------------------------------------+
# 2019-04-24 01:38:23.376183: I tensorflow/core/platform/profile_utils/cpu_utils.cc:94] CPU Frequency: 2300000000 Hz
# 2019-04-24 01:38:23.376670: I tensorflow/compiler/xla/service/service.cc:150] XLA service 0x15b49a0 executing computations on platform Host. Devices:
# 2019-04-24 01:38:23.376705: I tensorflow/compiler/xla/service/service.cc:158]   StreamExecutor device (0): <undefined>, <undefined>
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/op_def_library.py:263: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
#
# WARNING: The TensorFlow contrib module will not be included in TensorFlow 2.0.
# For more information, please see:
#   * https://github.com/tensorflow/community/blob/master/rfcs/20180907-contrib-sunset.md
#   * https://github.com/tensorflow/addons
# If you depend on functionality not listed there, please file an issue.
#
# WARNING:tensorflow:From /content/drive/My Drive/Project_Relation_Extraction/multihead_joint_entity_relation_extraction/tf_utils.py:375: BasicLSTMCell.__init__ (from tensorflow.python.ops.rnn_cell_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# This class is equivalent as tf.keras.layers.LSTMCell, and will be replaced by that in Tensorflow 2.0.
# WARNING:tensorflow:From /content/drive/My Drive/Project_Relation_Extraction/multihead_joint_entity_relation_extraction/tf_utils.py:381: bidirectional_dynamic_rnn (from tensorflow.python.ops.rnn) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `keras.layers.Bidirectional(keras.layers.RNN(cell))`, which is equivalent to this API
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/ops/rnn.py:443: dynamic_rnn (from tensorflow.python.ops.rnn) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `keras.layers.RNN(cell)`, which is equivalent to this API
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/ops/rnn.py:626: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# WARNING:tensorflow:From /content/drive/My Drive/Project_Relation_Extraction/multihead_joint_entity_relation_extraction/tf_utils.py:227: calling dropout (from tensorflow.python.ops.nn_ops) with keep_prob is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `rate` instead of `keep_prob`. Rate should be set to `rate = 1 - keep_prob`.
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/ops/gradients_impl.py:110: UserWarning: Converting sparse IndexedSlices to a dense Tensor of unknown shape. This may consume a large amount of memory.
#   "Converting sparse IndexedSlices to a dense Tensor of unknown shape. "
# ****iter 0****
# -------Train-------
# loss: 185063.585862
# +-----------------+----+----+------+----+----+----+
# |      Class      | TP | FP |  FN  | Pr | Re | F1 |
# +-----------------+----+----+------+----+----+----+
# |       Loc       | 0  | 5  | 1204 | 0  | 0  | 0  |
# |       Org       | 0  | 0  | 596  | 0  | 0  | 0  |
# |      Other      | 0  | 0  | 448  | 0  | 0  | 0  |
# |       Peop      | 0  | 6  | 1145 | 0  | 0  | 0  |
# |        -        | -  | -  |  -   | -  | -  | -  |
# | Micro NER chunk | 0  | 11 | 3393 | 0  | 0  | 0  |
# +-----------------+----+----+------+----+----+----+
# +-----------------+----+----+------+----+----+----+
# |      Class      | TP | FP |  FN  | Pr | Re | F1 |
# +-----------------+----+----+------+----+----+----+
# |       Kill      | 0  | 1  | 203  | 0  | 0  | 0  |
# |     Live_In     | 0  | 1  | 342  | 0  | 0  | 0  |
# |    Located_In   | 0  | 0  | 245  | 0  | 0  | 0  |
# |   OrgBased_In   | 0  | 1  | 241  | 0  | 0  | 0  |
# |     Work_For    | 0  | 3  | 242  | 0  | 0  | 0  |
# |        -        | -  | -  |  -   | -  | -  | -  |
# | Micro REL chunk | 0  | 6  | 1273 | 0  | 0  | 0  |
# +-----------------+----+----+------+----+----+----+
# Elapsed train time in sec:74.06753015518188
#
# -------Evaluate on dev-------
# +-----------------+----+----+-----+----+----+----+
# |      Class      | TP | FP |  FN | Pr | Re | F1 |
# +-----------------+----+----+-----+----+----+----+
# |       Loc       | 0  | 0  | 337 | 0  | 0  | 0  |
# |       Org       | 0  | 0  | 190 | 0  | 0  | 0  |
# |      Other      | 0  | 0  | 125 | 0  | 0  | 0  |
# |       Peop      | 0  | 0  | 225 | 0  | 0  | 0  |
# |        -        | -  | -  |  -  | -  | -  | -  |
# | Micro NER chunk | 0  | 0  | 877 | 0  | 0  | 0  |
# +-----------------+----+----+-----+----+----+----+
# +-----------------+----+----+-----+----+----+----+
# |      Class      | TP | FP |  FN | Pr | Re | F1 |
# +-----------------+----+----+-----+----+----+----+
# |       Kill      | 0  | 0  |  18 | 0  | 0  | 0  |
# |     Live_In     | 0  | 0  |  79 | 0  | 0  | 0  |
# |    Located_In   | 0  | 0  |  67 | 0  | 0  | 0  |
# |   OrgBased_In   | 0  | 0  | 106 | 0  | 0  | 0  |
# |     Work_For    | 0  | 0  |  83 | 0  | 0  | 0  |
# |        -        | -  | -  |  -  | -  | -  | -  |
# | Micro REL chunk | 0  | 0  | 353 | 0  | 0  | 0  |
# +-----------------+----+----+-----+----+----+----+
# -------Evaluate on test-------
# +-----------------+----+----+------+----+----+----+
# |      Class      | TP | FP |  FN  | Pr | Re | F1 |
# +-----------------+----+----+------+----+----+----+
# |       Loc       | 0  | 0  | 427  | 0  | 0  | 0  |
# |       Org       | 0  | 0  | 198  | 0  | 0  | 0  |
# |      Other      | 0  | 0  | 133  | 0  | 0  | 0  |
# |       Peop      | 0  | 0  | 321  | 0  | 0  | 0  |
# |        -        | -  | -  |  -   | -  | -  | -  |
# | Micro NER chunk | 0  | 0  | 1079 | 0  | 0  | 0  |
# +-----------------+----+----+------+----+----+----+
# +-----------------+----+----+-----+----+----+----+
# |      Class      | TP | FP |  FN | Pr | Re | F1 |
# +-----------------+----+----+-----+----+----+----+
# |       Kill      | 0  | 0  |  47 | 0  | 0  | 0  |
# |     Live_In     | 0  | 0  | 100 | 0  | 0  | 0  |
# |    Located_In   | 0  | 0  |  94 | 0  | 0  | 0  |
# |   OrgBased_In   | 0  | 0  | 105 | 0  | 0  | 0  |
# |     Work_For    | 0  | 0  |  76 | 0  | 0  | 0  |
# |        -        | -  | -  |  -  | -  | -  | -  |
# | Micro REL chunk | 0  | 0  | 422 | 0  | 0  | 0  |
# +-----------------+----+----+-----+----+----+----+
# Traceback (most recent call last):
#   File "train_es.py", line 64, in <module>
#     save_path=saver.save(sess,"./model.ckpt")
# NameError: name 'saver' is not defined
# /usr/local/lib/python3.6/dist-packages/smart_open/ssh.py:34: UserWarning: paramiko missing, opening SSH/SCP/SFTP paths will be disabled.  `pip install paramiko` to suppress
#   warnings.warn('paramiko missing, opening SSH/SCP/SFTP paths will be disabled.  `pip install paramiko` to suppress')
# /content/drive/My Drive/Project_Relation_Extraction/multihead_joint_entity_relation_extraction/parsers.py:68: FutureWarning: Method .as_matrix will be removed in a future version. Use .values instead.
#   engine='python', sep="\t", quoting=csv.QUOTE_NONE).as_matrix()
# +------------------------+--------------------------------------+
# |         Params         |                Value                 |
# +------------------------+--------------------------------------+
# |         Config         |     ./configs/CoNLL04/bio_config     |
# |       Embeddings       | data/CoNLL04/vecs.lc.over100freq.txt |
# |    Embeddings size     |                  50                  |
# |         Train          |        data/CoNLL04/train.txt        |
# |          Dev           |         data/CoNLL04/dev.txt         |
# |          Test          |        data/CoNLL04/test.txt         |
# |        Epochs          |                 150                  |
# |       Optimizer        |                 Adam                 |
# |      Activation        |                 tanh                 |
# |     Learning rate      |                0.001                 |
# |   Gradient clipping    |                False                 |
# |       Patience         |                  30                  |
# |      Use dropout       |                 True                 |
# |       Ner loss         |                 crf                  |
# |      Ner classes       |                 BIO                  |
# |  Use char embeddings   |                 True                 |
# |    Use adversarial     |                False                 |
# |   Dropout embedding    |                 0.9                  |
# |     Dropout lstm       |                 0.9                  |
# |  Dropout lstm output   |                 0.9                  |
# |    Dropout fcl ner     |                 1.0                  |
# |    Dropout fcl rel     |                 1.0                  |
# |   Hidden lstm size     |                  64                  |
# |      LSTM layers       |                  3                   |
# |    Hidden nn size      |                  64                  |
# | Char embeddings size   |                  25                  |
# |   Hidden size char     |                  25                  |
# | Label embeddings size  |                  0                   |
# |         Alpha          |                 0.01                 |
# |       Root node        |                False                 |
# |   Evaluation method    |                strict                |
# +------------------------+--------------------------------------+
# 2019-04-24 01:40:12.285214: I tensorflow/core/platform/profile_utils/cpu_utils.cc:94] CPU Frequency: 2300000000 Hz
# 2019-04-24 01:40:12.285628: I tensorflow/compiler/xla/service/service.cc:150] XLA service 0x24ec9a0 executing computations on platform Host. Devices:
# 2019-04-24 01:40:12.285672: I tensorflow/compiler/xla/service/service.cc:158]   StreamExecutor device (0): <undefined>, <undefined>
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/op_def_library.py:263: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
#
# WARNING: The TensorFlow contrib module will not be included in TensorFlow 2.0.
# For more information, please see:
#   * https://github.com/tensorflow/community/blob/master/rfcs/20180907-contrib-sunset.md
#   * https://github.com/tensorflow/addons
# If you depend on functionality not listed there, please file an issue.
#
# WARNING:tensorflow:From /content/drive/My Drive/Project_Relation_Extraction/multihead_joint_entity_relation_extraction/tf_utils.py:375: BasicLSTMCell.__init__ (from tensorflow.python.ops.rnn_cell_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# This class is equivalent as tf.keras.layers.LSTMCell, and will be replaced by that in Tensorflow 2.0.
# WARNING:tensorflow:From /content/drive/My Drive/Project_Relation_Extraction/multihead_joint_entity_relation_extraction/tf_utils.py:381: bidirectional_dynamic_rnn (from tensorflow.python.ops.rnn) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `keras.layers.Bidirectional(keras.layers.RNN(cell))`, which is equivalent to this API
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/ops/rnn.py:443: dynamic_rnn (from tensorflow.python.ops.rnn) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `keras.layers.RNN(cell)`, which is equivalent to this API
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/ops/rnn.py:626: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# WARNING:tensorflow:From /content/drive/My Drive/Project_Relation_Extraction/multihead_joint_entity_relation_extraction/tf_utils.py:227: calling dropout (from tensorflow.python.ops.nn_ops) with keep_prob is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `rate` instead of `keep_prob`. Rate should be set to `rate = 1 - keep_prob`.
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/ops/gradients_impl.py:110: UserWarning: Converting sparse IndexedSlices to a dense Tensor of unknown shape. This may consume a large amount of memory.
#   "Converting sparse IndexedSlices to a dense Tensor of unknown shape. "
# ****iter 0****
# -------Train-------
# loss: 216504.809245
# +-----------------+----+----+------+---------------------+-----------------------+-----------------------+
# |      Class      | TP | FP |  FN  |          Pr         |           Re          |           F1          |
# +-----------------+----+----+------+---------------------+-----------------------+-----------------------+
# |       Loc       | 1  | 5  | 1540 | 0.16666666666666666 | 0.0006489292667099286 |  0.001292824822236587 |
# |       Org       | 0  | 0  | 786  |          0          |           0           |           0           |
# |      Other      | 0  | 0  | 573  |          0          |           0           |           0           |
# |       Peop      | 0  | 6  | 1370 |          0          |           0           |           0           |
# |        -        | -  | -  |  -   |          -          |           -           |           -           |
# | Micro NER chunk | 1  | 11 | 4269 | 0.08333333333333333 |  0.000234192037470726 | 0.0004670714619336759 |
# +-----------------+----+----+------+---------------------+-----------------------+-----------------------+
# +-----------------+----+----+------+----+----+----+
# |      Class      | TP | FP |  FN  | Pr | Re | F1 |
# +-----------------+----+----+------+----+----+----+
# |       Kill      | 0  | 1  | 221  | 0  | 0  | 0  |
# |     Live_In     | 0  | 1  | 421  | 0  | 0  | 0  |
# |    Located_In   | 0  | 0  | 312  | 0  | 0  | 0  |
# |   OrgBased_In   | 0  | 1  | 347  | 0  | 0  | 0  |
# |     Work_For    | 0  | 3  | 325  | 0  | 0  | 0  |
# |        -        | -  | -  |  -   | -  | -  | -  |
# | Micro REL chunk | 0  | 6  | 1626 | 0  | 0  | 0  |
# +-----------------+----+----+------+----+----+----+
# Elapsed train time in sec:92.53879833221436
#
# -------Evaluate on test-------
# +-----------------+----+----+------+----+----+----+
# |      Class      | TP | FP |  FN  | Pr | Re | F1 |
# +-----------------+----+----+------+----+----+----+
# |       Loc       | 0  | 0  | 427  | 0  | 0  | 0  |
# |       Org       | 0  | 0  | 198  | 0  | 0  | 0  |
# |      Other      | 0  | 0  | 133  | 0  | 0  | 0  |
# |       Peop      | 0  | 0  | 321  | 0  | 0  | 0  |
# |        -        | -  | -  |  -   | -  | -  | -  |
# | Micro NER chunk | 0  | 0  | 1079 | 0  | 0  | 0  |
# +-----------------+----+----+------+----+----+----+
# +-----------------+----+----+-----+----+----+----+
# |      Class      | TP | FP |  FN | Pr | Re | F1 |
# +-----------------+----+----+-----+----+----+----+
# |       Kill      | 0  | 0  |  47 | 0  | 0  | 0  |
# |     Live_In     | 0  | 0  | 100 | 0  | 0  | 0  |
# |    Located_In   | 0  | 0  |  94 | 0  | 0  | 0  |
# |   OrgBased_In   | 0  | 0  | 105 | 0  | 0  | 0  |
# |     Work_For    | 0  | 0  |  76 | 0  | 0  | 0  |
# |        -        | -  | -  |  -  | -  | -  | -  |
# | Micro REL chunk | 0  | 0  | 422 | 0  | 0  | 0  |
# +-----------------+----+----+-----+----+----+----+
#
# - Test score 0.0 in 0 epoch
#
# ****iter 1****
# -------Train-------
# loss: 98991.859314
# +-----------------+----+----+------+---------------------+----------------------+----------------------+
# |      Class      | TP | FP |  FN  |          Pr         |          Re          |          F1          |
# +-----------------+----+----+------+---------------------+----------------------+----------------------+
# |       Loc       | 23 | 57 | 1518 |        0.2875       | 0.014925373134328358 |  0.0283775447254781  |
# |       Org       | 0  | 3  | 786  |          0          |          0           |          0           |
# |      Other      | 0  | 2  | 573  |          0          |          0           |          0           |
# |       Peop      | 0  | 2  | 1370 |          0          |          0           |          0           |
# |        -        | -  | -  |  -   |          -          |          -           |          -           |
# | Micro NER chunk | 23 | 64 | 4247 | 0.26436781609195403 | 0.005386416861826698 | 0.010557723204039476 |
# +-----------------+----+----+------+---------------------+----------------------+----------------------+
# +-----------------+----+----+------+----+----+----+
# |      Class      | TP | FP |  FN  | Pr | Re | F1 |
# +-----------------+----+----+------+----+----+----+
# |       Kill      | 0  | 0  | 221  | 0  | 0  | 0  |
# |     Live_In     | 0  | 0  | 421  | 0  | 0  | 0  |
# |    Located_In   | 0  | 0  | 312  | 0  | 0  | 0  |
# |   OrgBased_In   | 0  | 0  | 347  | 0  | 0  | 0  |
# |     Work_For    | 0  | 0  | 325  | 0  | 0  | 0  |
# |        -        | -  | -  |  -   | -  | -  | -  |
# | Micro REL chunk | 0  | 0  | 1626 | 0  | 0  | 0  |
# +-----------------+----+----+------+----+----+----+
# Elapsed train time in sec:87.98833060264587
#
# -------Evaluate on test-------
# +-----------------+----+----+------+--------------------+----------------------+---------------------+
# |      Class      | TP | FP |  FN  |         Pr         |          Re          |          F1         |
# +-----------------+----+----+------+--------------------+----------------------+---------------------+
# |       Loc       | 20 | 10 | 407  | 0.6666666666666666 |  0.0468384074941452  |  0.087527352297593  |
# |       Org       | 0  | 6  | 198  |         0          |          0           |          0          |
# |      Other      | 0  | 0  | 133  |         0          |          0           |          0          |
# |       Peop      | 0  | 0  | 321  |         0          |          0           |          0          |
# |        -        | -  | -  |  -   |         -          |          -           |          -          |
# | Micro NER chunk | 20 | 16 | 1059 | 0.5555555555555556 | 0.018535681186283594 | 0.03587443946188341 |
# +-----------------+----+----+------+--------------------+----------------------+---------------------+
# +-----------------+----+----+-----+----+----+----+
# |      Class      | TP | FP |  FN | Pr | Re | F1 |
# +-----------------+----+----+-----+----+----+----+
# |       Kill      | 0  | 0  |  47 | 0  | 0  | 0  |
# |     Live_In     | 0  | 0  | 100 | 0  | 0  | 0  |
# |    Located_In   | 0  | 0  |  94 | 0  | 0  | 0  |
# |   OrgBased_In   | 0  | 0  | 105 | 0  | 0  | 0  |
# |     Work_For    | 0  | 0  |  76 | 0  | 0  | 0  |
# |        -        | -  | -  |  -  | -  | -  | -  |
# | Micro REL chunk | 0  | 0  | 422 | 0  | 0  | 0  |
# +-----------------+----+----+-----+----+----+----+
#
# - Test score 0.017937219730941704 in 1 epoch
#
# ****iter 2****
# -------Train-------
# loss: 72273.467998
# +-----------------+----+-----+------+---------------------+----------------------+----------------------+
# |      Class      | TP |  FP |  FN  |          Pr         |          Re          |          F1          |
# +-----------------+----+-----+------+---------------------+----------------------+----------------------+
# |       Loc       | 49 |  96 | 1492 | 0.33793103448275863 |  0.0317975340687865  | 0.05812574139976275  |
# |       Org       | 7  |  17 | 779  |  0.2916666666666667 | 0.008905852417302799 | 0.017283950617283952 |
# |      Other      | 0  |  1  | 573  |          0          |          0           |          0           |
# |       Peop      | 0  |  3  | 1370 |          0          |          0           |          0           |
# |        -        | -  |  -  |  -   |          -          |          -           |          -           |
# | Micro NER chunk | 56 | 117 | 4214 |  0.3236994219653179 | 0.013114754098360656 | 0.025208192662615352 |
# +-----------------+----+-----+------+---------------------+----------------------+----------------------+
# +-----------------+----+----+------+----+----+----+
# |      Class      | TP | FP |  FN  | Pr | Re | F1 |
# +-----------------+----+----+------+----+----+----+
# |       Kill      | 0  | 0  | 221  | 0  | 0  | 0  |
# |     Live_In     | 0  | 0  | 421  | 0  | 0  | 0  |
# |    Located_In   | 0  | 0  | 312  | 0  | 0  | 0  |
# |   OrgBased_In   | 0  | 0  | 347  | 0  | 0  | 0  |
# |     Work_For    | 0  | 0  | 325  | 0  | 0  | 0  |
# |        -        | -  | -  |  -   | -  | -  | -  |
# | Micro REL chunk | 0  | 0  | 1626 | 0  | 0  | 0  |
# +-----------------+----+----+------+----+----+----+
# Elapsed train time in sec:88.14976191520691
#
# -------Evaluate on test-------
# +-----------------+----+----+------+---------------------+----------------------+----------------------+
# |      Class      | TP | FP |  FN  |          Pr         |          Re          |          F1          |
# +-----------------+----+----+------+---------------------+----------------------+----------------------+
# |       Loc       | 16 | 20 | 411  |  0.4444444444444444 | 0.03747072599531616  | 0.06911447084233262  |
# |       Org       | 6  | 8  | 192  | 0.42857142857142855 | 0.030303030303030304 | 0.056603773584905655 |
# |      Other      | 0  | 0  | 133  |          0          |          0           |          0           |
# |       Peop      | 0  | 0  | 321  |          0          |          0           |          0           |
# |        -        | -  | -  |  -   |          -          |          -           |          -           |
# | Micro NER chunk | 22 | 28 | 1057 |         0.44        | 0.020389249304911955 | 0.03897254207263064  |
# +-----------------+----+----+------+---------------------+----------------------+----------------------+
# +-----------------+----+----+-----+----+----+----+
# |      Class      | TP | FP |  FN | Pr | Re | F1 |
# +-----------------+----+----+-----+----+----+----+
# |       Kill      | 0  | 0  |  47 | 0  | 0  | 0  |
# |     Live_In     | 0  | 0  | 100 | 0  | 0  | 0  |
# |    Located_In   | 0  | 0  |  94 | 0  | 0  | 0  |
# |   OrgBased_In   | 0  | 0  | 105 | 0  | 0  | 0  |
# |     Work_For    | 0  | 0  |  76 | 0  | 0  | 0  |
# |        -        | -  | -  |  -  | -  | -  | -  |
# | Micro REL chunk | 0  | 0  | 422 | 0  | 0  | 0  |
# +-----------------+----+----+-----+----+----+----+
#
# - Test score 0.01948627103631532 in 2 epoch
#
# ****iter 3****
# -------Train-------
# loss: 59670.888093
# +-----------------+----+-----+------+---------------------+----------------------+----------------------+
# |      Class      | TP |  FP |  FN  |          Pr         |          Re          |          F1          |
# +-----------------+----+-----+------+---------------------+----------------------+----------------------+
# |       Loc       | 51 | 148 | 1490 |  0.2562814070351759 | 0.03309539260220636  | 0.05862068965517243  |
# |       Org       | 22 |  41 | 764  |  0.3492063492063492 | 0.027989821882951654 | 0.05182567726737339  |
# |      Other      | 0  |  7  | 573  |          0          |          0           |          0           |
# |       Peop      | 0  |  1  | 1370 |          0          |          0           |          0           |
# |        -        | -  |  -  |  -   |          -          |          -           |          -           |
# | Micro NER chunk | 73 | 197 | 4197 | 0.27037037037037037 | 0.017096018735362997 | 0.032158590308370046 |
# +-----------------+----+-----+------+---------------------+----------------------+----------------------+
# +-----------------+----+----+------+----+----+----+
# |      Class      | TP | FP |  FN  | Pr | Re | F1 |
# +-----------------+----+----+------+----+----+----+
# |       Kill      | 0  | 0  | 221  | 0  | 0  | 0  |
# |     Live_In     | 0  | 0  | 421  | 0  | 0  | 0  |
# |    Located_In   | 0  | 0  | 312  | 0  | 0  | 0  |
# |   OrgBased_In   | 0  | 0  | 347  | 0  | 0  | 0  |
# |     Work_For    | 0  | 0  | 325  | 0  | 0  | 0  |
# |        -        | -  | -  |  -   | -  | -  | -  |
# | Micro REL chunk | 0  | 0  | 1626 | 0  | 0  | 0  |
# +-----------------+----+----+------+----+----+----+
# Elapsed train time in sec:89.26389527320862
#
# -------Evaluate on test-------
# +-----------------+----+----+------+--------------------+----------------------+----------------------+
# |      Class      | TP | FP |  FN  |         Pr         |          Re          |          F1          |
# +-----------------+----+----+------+--------------------+----------------------+----------------------+
# |       Loc       | 19 | 23 | 408  | 0.4523809523809524 | 0.04449648711943794  | 0.08102345415778252  |
# |       Org       | 7  | 17 | 191  | 0.2916666666666667 | 0.03535353535353535  | 0.06306306306306306  |
# |      Other      | 0  | 0  | 133  |         0          |          0           |          0           |
# |       Peop      | 0  | 0  | 321  |         0          |          0           |          0           |
# |        -        | -  | -  |  -   |         -          |          -           |          -           |
# | Micro NER chunk | 26 | 40 | 1053 | 0.3939393939393939 | 0.024096385542168676 | 0.045414847161572056 |
# +-----------------+----+----+------+--------------------+----------------------+----------------------+
# +-----------------+----+----+-----+----+----+----+
# |      Class      | TP | FP |  FN | Pr | Re | F1 |
# +-----------------+----+----+-----+----+----+----+
# |       Kill      | 0  | 0  |  47 | 0  | 0  | 0  |
# |     Live_In     | 0  | 0  | 100 | 0  | 0  | 0  |
# |    Located_In   | 0  | 0  |  94 | 0  | 0  | 0  |
# |   OrgBased_In   | 0  | 0  | 105 | 0  | 0  | 0  |
# |     Work_For    | 0  | 0  |  76 | 0  | 0  | 0  |
# |        -        | -  | -  |  -  | -  | -  | -  |
# | Micro REL chunk | 0  | 0  | 422 | 0  | 0  | 0  |
# +-----------------+----+----+-----+----+----+----+
#
# - Test score 0.022707423580786028 in 3 epoch
#
# ****iter 4****
# -------Train-------
# loss: 51848.280843
# +-----------------+-----+-----+------+---------------------+----------------------+----------------------+
# |      Class      |  TP |  FP |  FN  |          Pr         |          Re          |          F1          |
# +-----------------+-----+-----+------+---------------------+----------------------+----------------------+
# |       Loc       |  83 | 125 | 1458 | 0.39903846153846156 | 0.05386112913692408  | 0.09491137793024586  |
# |       Org       |  26 |  52 | 760  |  0.3333333333333333 | 0.03307888040712468  | 0.060185185185185175 |
# |      Other      |  0  |  15 | 573  |          0          |          0           |          0           |
# |       Peop      |  0  |  2  | 1370 |          0          |          0           |          0           |
# |        -        |  -  |  -  |  -   |          -          |          -           |          -           |
# | Micro NER chunk | 109 | 194 | 4161 | 0.35973597359735976 | 0.025526932084309135 | 0.04767111305488739  |
# +-----------------+-----+-----+------+---------------------+----------------------+----------------------+
# +-----------------+----+----+------+-----+-----------------------+----------------------+
# |      Class      | TP | FP |  FN  |  Pr |           Re          |          F1          |
# +-----------------+----+----+------+-----+-----------------------+----------------------+
# |       Kill      | 0  | 0  | 221  |  0  |           0           |          0           |
# |     Live_In     | 0  | 0  | 421  |  0  |           0           |          0           |
# |    Located_In   | 0  | 0  | 312  |  0  |           0           |          0           |
# |   OrgBased_In   | 1  | 0  | 346  | 1.0 |  0.002881844380403458 | 0.005747126436781608 |
# |     Work_For    | 0  | 0  | 325  |  0  |           0           |          0           |
# |        -        | -  | -  |  -   |  -  |           -           |          -           |
# | Micro REL chunk | 1  | 0  | 1625 | 1.0 | 0.0006150061500615006 | 0.001229256299938537 |
# +-----------------+----+----+------+-----+-----------------------+----------------------+
# Elapsed train time in sec:88.93912434577942
#
# -------Evaluate on test-------
# +-----------------+----+----+------+---------------------+----------------------+---------------------+
# |      Class      | TP | FP |  FN  |          Pr         |          Re          |          F1         |
# +-----------------+----+----+------+---------------------+----------------------+---------------------+
# |       Loc       | 22 | 24 | 405  |  0.4782608695652174 | 0.05152224824355972  |  0.0930232558139535 |
# |       Org       | 9  | 13 | 189  |  0.4090909090909091 | 0.045454545454545456 | 0.08181818181818182 |
# |      Other      | 0  | 0  | 133  |          0          |          0           |          0          |
# |       Peop      | 0  | 0  | 321  |          0          |          0           |          0          |
# |        -        | -  | -  |  -   |          -          |          -           |          -          |
# | Micro NER chunk | 31 | 37 | 1048 | 0.45588235294117646 | 0.028730305838739572 | 0.05405405405405405 |
# +-----------------+----+----+------+---------------------+----------------------+---------------------+
# +-----------------+----+----+-----+----+----+----+
# |      Class      | TP | FP |  FN | Pr | Re | F1 |
# +-----------------+----+----+-----+----+----+----+
# |       Kill      | 0  | 0  |  47 | 0  | 0  | 0  |
# |     Live_In     | 0  | 0  | 100 | 0  | 0  | 0  |
# |    Located_In   | 0  | 0  |  94 | 0  | 0  | 0  |
# |   OrgBased_In   | 0  | 0  | 105 | 0  | 0  | 0  |
# |     Work_For    | 0  | 0  |  76 | 0  | 0  | 0  |
# |        -        | -  | -  |  -  | -  | -  | -  |
# | Micro REL chunk | 0  | 0  | 422 | 0  | 0  | 0  |
# +-----------------+----+----+-----+----+----+----+
#
# - Test score 0.027027027027027025 in 4 epoch
#
# ****iter 5****
# -------Train-------
# loss: 46639.182217
# +-----------------+-----+-----+------+---------------------+-----------------------+----------------------+
# |      Class      |  TP |  FP |  FN  |          Pr         |           Re          |          F1          |
# +-----------------+-----+-----+------+---------------------+-----------------------+----------------------+
# |       Loc       | 128 | 161 | 1413 |  0.4429065743944637 |  0.08306294613887086  | 0.13989071038251363  |
# |       Org       |  37 |  61 | 749  | 0.37755102040816324 |  0.047073791348600506 |  0.083710407239819   |
# |      Other      |  2  |  29 | 571  | 0.06451612903225806 | 0.0034904013961605585 | 0.006622516556291392 |
# |       Peop      |  0  |  4  | 1370 |          0          |           0           |          0           |
# |        -        |  -  |  -  |  -   |          -          |           -           |          -           |
# | Micro NER chunk | 167 | 255 | 4103 |  0.3957345971563981 |  0.03911007025761124  |  0.0711849957374254  |
# +-----------------+-----+-----+------+---------------------+-----------------------+----------------------+
# +-----------------+----+----+------+--------------------+----------------------+----------------------+
# |      Class      | TP | FP |  FN  |         Pr         |          Re          |          F1          |
# +-----------------+----+----+------+--------------------+----------------------+----------------------+
# |       Kill      | 0  | 0  | 221  |         0          |          0           |          0           |
# |     Live_In     | 0  | 0  | 421  |         0          |          0           |          0           |
# |    Located_In   | 1  | 0  | 311  |        1.0         | 0.003205128205128205 | 0.006389776357827476 |
# |   OrgBased_In   | 6  | 4  | 341  |        0.6         | 0.01729106628242075  | 0.033613445378151266 |
# |     Work_For    | 0  | 0  | 325  |         0          |          0           |          0           |
# |        -        | -  | -  |  -   |         -          |          -           |          -           |
# | Micro REL chunk | 7  | 4  | 1619 | 0.6363636363636364 | 0.004305043050430504 | 0.00855222968845449  |
# +-----------------+----+----+------+--------------------+----------------------+----------------------+
# Elapsed train time in sec:88.97525310516357
#
# -------Evaluate on test-------
# +-----------------+----+----+------+--------------------+----------------------+---------------------+
# |      Class      | TP | FP |  FN  |         Pr         |          Re          |          F1         |
# +-----------------+----+----+------+--------------------+----------------------+---------------------+
# |       Loc       | 20 | 30 | 407  |        0.4         |  0.0468384074941452  |  0.0838574423480084 |
# |       Org       | 16 | 15 | 182  | 0.5161290322580645 | 0.08080808080808081  | 0.13973799126637557 |
# |      Other      | 0  | 19 | 133  |         0          |          0           |          0          |
# |       Peop      | 0  | 0  | 321  |         0          |          0           |          0          |
# |        -        | -  | -  |  -   |         -          |          -           |          -          |
# | Micro NER chunk | 36 | 64 | 1043 |        0.36        | 0.033364226135310475 | 0.06106870229007634 |
# +-----------------+----+----+------+--------------------+----------------------+---------------------+
# +-----------------+----+----+-----+------+----------------------+----------------------+
# |      Class      | TP | FP |  FN |  Pr  |          Re          |          F1          |
# +-----------------+----+----+-----+------+----------------------+----------------------+
# |       Kill      | 0  | 0  |  47 |  0   |          0           |          0           |
# |     Live_In     | 0  | 0  | 100 |  0   |          0           |          0           |
# |    Located_In   | 0  | 0  |  94 |  0   |          0           |          0           |
# |   OrgBased_In   | 6  | 2  |  99 | 0.75 | 0.05714285714285714  | 0.10619469026548672  |
# |     Work_For    | 0  | 0  |  76 |  0   |          0           |          0           |
# |        -        | -  | -  |  -  |  -   |          -           |          -           |
# | Micro REL chunk | 6  | 2  | 416 | 0.75 | 0.014218009478672985 | 0.027906976744186043 |
# +-----------------+----+----+-----+------+----------------------+----------------------+
#
# - Test score 0.04448783951713119 in 5 epoch
#
# ****iter 6****
# -------Train-------
# loss: 45911.291181
# +-----------------+-----+-----+------+---------------------+---------------------+-----------------------+
# |      Class      |  TP |  FP |  FN  |          Pr         |          Re         |           F1          |
# +-----------------+-----+-----+------+---------------------+---------------------+-----------------------+
# |       Loc       | 131 | 190 | 1410 | 0.40809968847352024 | 0.08500973393900065 |   0.1407089151450054  |
# |       Org       |  47 |  62 | 739  | 0.43119266055045874 | 0.05979643765903308 |  0.10502793296089385  |
# |      Other      |  0  |  49 | 573  |          0          |          0          |           0           |
# |       Peop      |  2  |  17 | 1368 | 0.10526315789473684 | 0.00145985401459854 | 0.0028797696184305254 |
# |        -        |  -  |  -  |  -   |          -          |          -          |           -           |
# | Micro NER chunk | 180 | 318 | 4090 |  0.3614457831325301 | 0.04215456674473068 |  0.07550335570469799  |
# +-----------------+-----+-----+------+---------------------+---------------------+-----------------------+
# +-----------------+----+----+------+--------------------+----------------------+----------------------+
# |      Class      | TP | FP |  FN  |         Pr         |          Re          |          F1          |
# +-----------------+----+----+------+--------------------+----------------------+----------------------+
# |       Kill      | 0  | 0  | 221  |         0          |          0           |          0           |
# |     Live_In     | 0  | 0  | 421  |         0          |          0           |          0           |
# |    Located_In   | 0  | 0  | 312  |         0          |          0           |          0           |
# |   OrgBased_In   | 14 | 1  | 333  | 0.9333333333333333 | 0.040345821325648415 | 0.07734806629834254  |
# |     Work_For    | 0  | 0  | 325  |         0          |          0           |          0           |
# |        -        | -  | -  |  -   |         -          |          -           |          -           |
# | Micro REL chunk | 14 | 1  | 1612 | 0.9333333333333333 | 0.008610086100861008 | 0.017062766605728214 |
# +-----------------+----+----+------+--------------------+----------------------+----------------------+
# Elapsed train time in sec:88.18316793441772
#
# -------Evaluate on test-------
# +-----------------+----+----+------+--------------------+----------------------+----------------------+
# |      Class      | TP | FP |  FN  |         Pr         |          Re          |          F1          |
# +-----------------+----+----+------+--------------------+----------------------+----------------------+
# |       Loc       | 28 | 36 | 399  |       0.4375       | 0.06557377049180328  | 0.11405295315682282  |
# |       Org       | 16 | 15 | 182  | 0.5161290322580645 | 0.08080808080808081  | 0.13973799126637557  |
# |      Other      | 2  | 14 | 131  |       0.125        | 0.015037593984962405 | 0.026845637583892617 |
# |       Peop      | 0  | 1  | 321  |         0          |          0           |          0           |
# |        -        | -  | -  |  -   |         -          |          -           |          -           |
# | Micro NER chunk | 46 | 66 | 1033 | 0.4107142857142857 | 0.042632066728452274 | 0.07724601175482787  |
# +-----------------+----+----+------+--------------------+----------------------+----------------------+
# +-----------------+----+----+-----+-----+----------------------+----------------------+
# |      Class      | TP | FP |  FN |  Pr |          Re          |          F1          |
# +-----------------+----+----+-----+-----+----------------------+----------------------+
# |       Kill      | 0  | 0  |  47 |  0  |          0           |          0           |
# |     Live_In     | 0  | 0  | 100 |  0  |          0           |          0           |
# |    Located_In   | 0  | 0  |  94 |  0  |          0           |          0           |
# |   OrgBased_In   | 1  | 0  | 104 | 1.0 | 0.009523809523809525 | 0.01886792452830189  |
# |     Work_For    | 0  | 0  |  76 |  0  |          0           |          0           |
# |        -        | -  | -  |  -  |  -  |          -           |          -           |
# | Micro REL chunk | 1  | 0  | 421 | 1.0 | 0.002369668246445498 | 0.004728132387706856 |
# +-----------------+----+----+-----+-----+----------------------+----------------------+
#
# - Test score 0.040987072071267366 in 6 epoch
#
# ****iter 7****
# -------Train-------
# loss: 60416.278084
# +-----------------+----+-----+------+---------------------+-----------------------+----------------------+
# |      Class      | TP |  FP |  FN  |          Pr         |           Re          |          F1          |
# +-----------------+----+-----+------+---------------------+-----------------------+----------------------+
# |       Loc       | 71 | 220 | 1470 | 0.24398625429553264 |  0.046073977936404935 |  0.0775109170305677  |
# |       Org       | 21 |  44 | 765  |  0.3230769230769231 |  0.026717557251908396 | 0.04935370152761457  |
# |      Other      | 2  |  24 | 571  | 0.07692307692307693 | 0.0034904013961605585 | 0.006677796327212021 |
# |       Peop      | 3  |  40 | 1367 | 0.06976744186046512 | 0.0021897810218978104 | 0.004246284501061572 |
# |        -        | -  |  -  |  -   |          -          |           -           |          -           |
# | Micro NER chunk | 97 | 328 | 4173 | 0.22823529411764706 |  0.02271662763466042  | 0.04132055378061768  |
# +-----------------+----+-----+------+---------------------+-----------------------+----------------------+
# +-----------------+----+----+------+--------------------+-----------------------+-----------------------+
# |      Class      | TP | FP |  FN  |         Pr         |           Re          |           F1          |
# +-----------------+----+----+------+--------------------+-----------------------+-----------------------+
# |       Kill      | 0  | 1  | 221  |         0          |           0           |           0           |
# |     Live_In     | 0  | 0  | 421  |         0          |           0           |           0           |
# |    Located_In   | 0  | 5  | 312  |         0          |           0           |           0           |
# |   OrgBased_In   | 3  | 6  | 344  | 0.3333333333333333 |  0.008645533141210375 |  0.016853932584269666 |
# |     Work_For    | 0  | 0  | 325  |         0          |           0           |           0           |
# |        -        | -  | -  |  -   |         -          |           -           |           -           |
# | Micro REL chunk | 3  | 12 | 1623 |        0.2         | 0.0018450184501845018 | 0.0036563071297989027 |
# +-----------------+----+----+------+--------------------+-----------------------+-----------------------+
# Elapsed train time in sec:87.50184559822083
#
# -------Evaluate on test-------
# +-----------------+----+----+------+---------------------+----------------------+---------------------+
# |      Class      | TP | FP |  FN  |          Pr         |          Re          |          F1         |
# +-----------------+----+----+------+---------------------+----------------------+---------------------+
# |       Loc       | 26 | 29 | 401  |  0.4727272727272727 | 0.06088992974238876  |  0.1078838174273859 |
# |       Org       | 10 | 12 | 188  | 0.45454545454545453 | 0.050505050505050504 |  0.0909090909090909 |
# |      Other      | 0  | 0  | 133  |          0          |          0           |          0          |
# |       Peop      | 6  | 42 | 315  |        0.125        | 0.018691588785046728 | 0.03252032520325203 |
# |        -        | -  | -  |  -   |          -          |          -           |          -          |
# | Micro NER chunk | 42 | 83 | 1037 |        0.336        | 0.03892493049119555  | 0.06976744186046512 |
# +-----------------+----+----+------+---------------------+----------------------+---------------------+
# +-----------------+----+----+-----+----+----+----+
# |      Class      | TP | FP |  FN | Pr | Re | F1 |
# +-----------------+----+----+-----+----+----+----+
# |       Kill      | 0  | 0  |  47 | 0  | 0  | 0  |
# |     Live_In     | 0  | 0  | 100 | 0  | 0  | 0  |
# |    Located_In   | 0  | 0  |  94 | 0  | 0  | 0  |
# |   OrgBased_In   | 0  | 0  | 105 | 0  | 0  | 0  |
# |     Work_For    | 0  | 0  |  76 | 0  | 0  | 0  |
# |        -        | -  | -  |  -  | -  | -  | -  |
# | Micro REL chunk | 0  | 0  | 422 | 0  | 0  | 0  |
# +-----------------+----+----+-----+----+----+----+
#
# - Test score 0.03488372093023256 in 7 epoch
#
# ****iter 8****
# -------Train-------
# loss: 38957.870027
# +-----------------+------+------+------+---------------------+-----------------------+-----------------------+
# |      Class      |  TP  |  FP  |  FN  |          Pr         |           Re          |           F1          |
# +-----------------+------+------+------+---------------------+-----------------------+-----------------------+
# |       Loc       | 479  | 787  | 1062 |  0.3783570300157978 |   0.3108371187540558  |   0.3412896330602066  |
# |       Org       |  43  | 152  | 743  |  0.2205128205128205 |  0.054707379134860054 |  0.08766564729867482  |
# |      Other      |  1   |  18  | 572  | 0.05263157894736842 | 0.0017452006980802793 | 0.0033783783783783786 |
# |       Peop      | 570  | 714  | 800  |  0.4439252336448598 |  0.41605839416058393  |  0.42954031650339103  |
# |        -        |  -   |  -   |  -   |          -          |           -           |           -           |
# | Micro NER chunk | 1093 | 1671 | 3177 |  0.3954413892908828 |   0.2559718969555035  |  0.31077622974125674  |
# +-----------------+------+------+------+---------------------+-----------------------+-----------------------+
# +-----------------+----+----+------+----+----+----+
# |      Class      | TP | FP |  FN  | Pr | Re | F1 |
# +-----------------+----+----+------+----+----+----+
# |       Kill      | 0  | 0  | 221  | 0  | 0  | 0  |
# |     Live_In     | 0  | 0  | 421  | 0  | 0  | 0  |
# |    Located_In   | 0  | 0  | 312  | 0  | 0  | 0  |
# |   OrgBased_In   | 0  | 1  | 347  | 0  | 0  | 0  |
# |     Work_For    | 0  | 0  | 325  | 0  | 0  | 0  |
# |        -        | -  | -  |  -   | -  | -  | -  |
# | Micro REL chunk | 0  | 1  | 1626 | 0  | 0  | 0  |
# +-----------------+----+----+------+----+----+----+
# Elapsed train time in sec:87.6766746044159
#
# -------Evaluate on test-------
# +-----------------+-----+-----+-----+---------------------+---------------------+---------------------+
# |      Class      |  TP |  FP |  FN |          Pr         |          Re         |          F1         |
# +-----------------+-----+-----+-----+---------------------+---------------------+---------------------+
# |       Loc       | 156 | 181 | 271 |  0.4629080118694362 | 0.36533957845433257 |  0.4083769633507854 |
# |       Org       |  15 |  39 | 183 |  0.2777777777777778 | 0.07575757575757576 | 0.11904761904761905 |
# |      Other      |  0  |  9  | 133 |          0          |          0          |          0          |
# |       Peop      | 196 | 305 | 125 |  0.3912175648702595 |  0.6105919003115264 |  0.4768856447688564 |
# |        -        |  -  |  -  |  -  |          -          |          -          |          -          |
# | Micro NER chunk | 367 | 534 | 712 | 0.40732519422863483 |  0.340129749768304  |  0.3707070707070707 |
# +-----------------+-----+-----+-----+---------------------+---------------------+---------------------+
# +-----------------+----+----+-----+----+----+----+
# ...
# |   OrgBased_In   | 337  | 13 | 10 | 0.9628571428571429 | 0.9711815561959655 | 0.9670014347202295 |
# |     Work_For    | 309  | 15 | 16 | 0.9537037037037037 | 0.9507692307692308 | 0.9522342064714947 |
# |        -        |  -   | -  | -  |         -          |         -          |         -          |
# | Micro REL chunk | 1576 | 48 | 50 | 0.9704433497536946 | 0.9692496924969249 | 0.9698461538461538 |
# +-----------------+------+----+----+--------------------+--------------------+--------------------+
# Elapsed train time in sec:84.34704828262329
#
# -------Evaluate on test-------
# +-----------------+-----+-----+-----+--------------------+--------------------+--------------------+
# |      Class      |  TP |  FP |  FN |         Pr         |         Re         |         F1         |
# +-----------------+-----+-----+-----+--------------------+--------------------+--------------------+
# |       Loc       | 380 |  54 |  47 | 0.8755760368663594 | 0.8899297423887588 | 0.8826945412311266 |
# |       Org       | 156 |  61 |  42 | 0.7188940092165899 | 0.7878787878787878 | 0.7518072289156627 |
# |      Other      |  79 |  35 |  54 | 0.6929824561403509 | 0.5939849624060151 | 0.6396761133603239 |
# |       Peop      | 297 |  41 |  24 | 0.878698224852071  | 0.9252336448598131 | 0.9013657056145675 |
# |        -        |  -  |  -  |  -  |         -          |         -          |         -          |
# | Micro NER chunk | 912 | 191 | 167 | 0.8268359020852222 | 0.845227062094532  | 0.8359303391384052 |
# +-----------------+-----+-----+-----+--------------------+--------------------+--------------------+
# +-----------------+-----+-----+-----+--------------------+--------------------+--------------------+
# |      Class      |  TP |  FP |  FN |         Pr         |         Re         |         F1         |
# +-----------------+-----+-----+-----+--------------------+--------------------+--------------------+
# |       Kill      |  39 |  13 |  8  |        0.75        | 0.8297872340425532 | 0.787878787878788  |
# |     Live_In     |  56 |  35 |  44 | 0.6153846153846154 |        0.56        | 0.5863874345549739 |
# |    Located_In   |  45 |  40 |  49 | 0.5294117647058824 | 0.4787234042553192 | 0.5027932960893855 |
# |   OrgBased_In   |  55 |  29 |  50 | 0.6547619047619048 | 0.5238095238095238 | 0.582010582010582  |
# |     Work_For    |  43 |  28 |  33 | 0.6056338028169014 | 0.5657894736842105 | 0.5850340136054422 |
# |        -        |  -  |  -  |  -  |         -          |         -          |         -          |
# | Micro REL chunk | 238 | 145 | 184 | 0.6214099216710183 | 0.5639810426540285 | 0.5913043478260869 |
# +-----------------+-----+-----+-----+--------------------+--------------------+--------------------+
#
# - Test score 0.713617343482246 in 147 epoch
#
# ****iter 148****
# -------Train-------
# loss: 655.886895
# +-----------------+------+----+----+--------------------+--------------------+--------------------+
# |      Class      |  TP  | FP | FN |         Pr         |         Re         |         F1         |
# +-----------------+------+----+----+--------------------+--------------------+--------------------+
# |       Loc       | 1527 | 16 | 14 | 0.9896305897602073 | 0.990914990266061  | 0.9902723735408561 |
# |       Org       | 781  | 8  | 5  | 0.9898605830164765 | 0.9936386768447837 | 0.9917460317460317 |
# |      Other      | 548  | 19 | 25 | 0.9664902998236331 | 0.956369982547993  | 0.9614035087719298 |
# |       Peop      | 1359 | 12 | 11 | 0.9912472647702407 | 0.9919708029197081 | 0.991608901860635  |
# |        -        |  -   | -  | -  |         -          |         -          |         -          |
# | Micro NER chunk | 4215 | 55 | 55 | 0.9871194379391101 | 0.9871194379391101 | 0.9871194379391101 |
# +-----------------+------+----+----+--------------------+--------------------+--------------------+
# +-----------------+------+----+----+--------------------+--------------------+--------------------+
# |      Class      |  TP  | FP | FN |         Pr         |         Re         |         F1         |
# +-----------------+------+----+----+--------------------+--------------------+--------------------+
# |       Kill      | 217  | 5  | 4  | 0.9774774774774775 | 0.9819004524886877 | 0.9796839729119639 |
# |     Live_In     | 403  | 15 | 18 | 0.9641148325358851 | 0.9572446555819477 | 0.9606674612634087 |
# |    Located_In   | 298  | 9  | 14 | 0.9706840390879479 | 0.9551282051282052 | 0.962843295638126  |
# |   OrgBased_In   | 333  | 16 | 14 | 0.9541547277936963 | 0.9596541786743515 | 0.9568965517241379 |
# |     Work_For    | 312  | 9  | 13 | 0.9719626168224299 |        0.96        | 0.9659442724458204 |
# |        -        |  -   | -  | -  |         -          |         -          |         -          |
# | Micro REL chunk | 1563 | 54 | 63 | 0.9666048237476809 | 0.9612546125461254 | 0.963922294172063  |
# +-----------------+------+----+----+--------------------+--------------------+--------------------+
# Elapsed train time in sec:85.4085214138031
#
# -------Evaluate on test-------
# +-----------------+-----+-----+-----+--------------------+--------------------+--------------------+
# |      Class      |  TP |  FP |  FN |         Pr         |         Re         |         F1         |
# +-----------------+-----+-----+-----+--------------------+--------------------+--------------------+
# |       Loc       | 376 |  55 |  51 | 0.8723897911832946 | 0.8805620608899297 | 0.8764568764568764 |
# |       Org       | 148 |  52 |  50 |        0.74        | 0.7474747474747475 | 0.743718592964824  |
# |      Other      |  84 |  45 |  49 | 0.6511627906976745 | 0.631578947368421  | 0.6412213740458015 |
# |       Peop      | 287 |  44 |  34 | 0.8670694864048338 | 0.8940809968847352 | 0.8803680981595091 |
# |        -        |  -  |  -  |  -  |         -          |         -          |         -          |
# | Micro NER chunk | 895 | 196 | 184 | 0.8203483043079743 | 0.8294717330861909 | 0.8248847926267282 |
# +-----------------+-----+-----+-----+--------------------+--------------------+--------------------+
# +-----------------+-----+-----+-----+--------------------+---------------------+--------------------+
# |      Class      |  TP |  FP |  FN |         Pr         |          Re         |         F1         |
# +-----------------+-----+-----+-----+--------------------+---------------------+--------------------+
# |       Kill      |  39 |  10 |  8  | 0.7959183673469388 |  0.8297872340425532 |       0.8125       |
# |     Live_In     |  51 |  43 |  49 | 0.5425531914893617 |         0.51        | 0.5257731958762887 |
# |    Located_In   |  41 |  26 |  53 | 0.6119402985074627 | 0.43617021276595747 | 0.5093167701863355 |
# |   OrgBased_In   |  54 |  17 |  51 | 0.7605633802816901 |  0.5142857142857142 | 0.6136363636363636 |
# |     Work_For    |  38 |  29 |  38 | 0.5671641791044776 |         0.5         | 0.5314685314685315 |
# |        -        |  -  |  -  |  -  |         -          |          -          |         -          |
# | Micro REL chunk | 223 | 125 | 199 | 0.6408045977011494 |  0.5284360189573459 | 0.5792207792207792 |
# +-----------------+-----+-----+-----+--------------------+---------------------+--------------------+
#
# - Test score 0.7020527859237538 in 148 epoch
#
# ****iter 149****
# -------Train-------
# loss: 659.819908
# +-----------------+------+----+----+--------------------+--------------------+--------------------+
# |      Class      |  TP  | FP | FN |         Pr         |         Re         |         F1         |
# +-----------------+------+----+----+--------------------+--------------------+--------------------+
# |       Loc       | 1525 | 14 | 16 |  0.99090318388564  | 0.9896171317326411 | 0.9902597402597403 |
# |       Org       | 775  | 13 | 11 | 0.983502538071066  | 0.9860050890585241 | 0.9847522236340533 |
# |      Other      | 550  | 22 | 23 | 0.9615384615384616 | 0.9598603839441536 | 0.9606986899563319 |
# |       Peop      | 1357 | 10 | 13 | 0.9926847110460864 | 0.9905109489051095 | 0.9915966386554623 |
# |        -        |  -   | -  | -  |         -          |         -          |         -          |
# | Micro NER chunk | 4207 | 59 | 63 | 0.9861697140178153 | 0.9852459016393442 | 0.9857075913776945 |
# +-----------------+------+----+----+--------------------+--------------------+--------------------+
# +-----------------+------+----+----+--------------------+--------------------+--------------------+
# |      Class      |  TP  | FP | FN |         Pr         |         Re         |         F1         |
# +-----------------+------+----+----+--------------------+--------------------+--------------------+
# |       Kill      | 215  | 4  | 6  | 0.9817351598173516 | 0.9728506787330317 | 0.9772727272727273 |
# |     Live_In     | 404  | 14 | 17 | 0.9665071770334929 | 0.9596199524940617 | 0.9630512514898688 |
# |    Located_In   | 300  | 9  | 12 | 0.970873786407767  | 0.9615384615384616 | 0.966183574879227  |
# |   OrgBased_In   | 337  | 14 | 10 | 0.9601139601139601 | 0.9711815561959655 | 0.9656160458452723 |
# |     Work_For    | 311  | 9  | 14 |      0.971875      | 0.9569230769230769 | 0.9643410852713179 |
# |        -        |  -   | -  | -  |         -          |         -          |         -          |
# | Micro REL chunk | 1567 | 50 | 59 | 0.969078540507112  | 0.9637146371463715 | 0.9663891458526056 |
# +-----------------+------+----+----+--------------------+--------------------+--------------------+
# Elapsed train time in sec:86.8137948513031
#
# -------Evaluate on test-------
# +-----------------+-----+-----+-----+--------------------+--------------------+--------------------+
# |      Class      |  TP |  FP |  FN |         Pr         |         Re         |         F1         |
# +-----------------+-----+-----+-----+--------------------+--------------------+--------------------+
# |       Loc       | 381 |  58 |  46 | 0.8678815489749431 | 0.892271662763466  | 0.8799076212471132 |
# |       Org       | 149 |  61 |  49 | 0.7095238095238096 | 0.7525252525252525 | 0.7303921568627451 |
# |      Other      |  85 |  34 |  48 | 0.7142857142857143 | 0.6390977443609023 | 0.6746031746031745 |
# |       Peop      | 293 |  43 |  28 | 0.8720238095238095 | 0.9127725856697819 | 0.8919330289193304 |
# |        -        |  -  |  -  |  -  |         -          |         -          |         -          |
# | Micro NER chunk | 908 | 196 | 171 | 0.822463768115942  | 0.8415199258572753 | 0.831882730187815  |
# +-----------------+-----+-----+-----+--------------------+--------------------+--------------------+
# +-----------------+-----+-----+-----+--------------------+--------------------+---------------------+
# |      Class      |  TP |  FP |  FN |         Pr         |         Re         |          F1         |
# +-----------------+-----+-----+-----+--------------------+--------------------+---------------------+
# |       Kill      |  35 |  8  |  12 | 0.813953488372093  | 0.7446808510638298 |  0.7777777777777778 |
# |     Live_In     |  47 |  39 |  53 | 0.5465116279069767 |        0.47        |  0.5053763440860215 |
# |    Located_In   |  35 |  14 |  59 | 0.7142857142857143 | 0.3723404255319149 | 0.48951048951048953 |
# |   OrgBased_In   |  57 |  24 |  48 | 0.7037037037037037 | 0.5428571428571428 |  0.6129032258064516 |
# |     Work_For    |  43 |  28 |  33 | 0.6056338028169014 | 0.5657894736842105 |  0.5850340136054422 |
# |        -        |  -  |  -  |  -  |         -          |         -          |          -          |
# | Micro REL chunk | 217 | 113 | 205 | 0.6575757575757576 | 0.514218009478673  |  0.577127659574468  |
# +-----------------+-----+-----+-----+--------------------+--------------------+---------------------+
#
# - Test score 0.7045051948811415 in 149 epoch
#
# ****iter 150****
# -------Train-------
# loss: 616.616314
# +-----------------+------+----+----+--------------------+--------------------+--------------------+
# |      Class      |  TP  | FP | FN |         Pr         |         Re         |         F1         |
# +-----------------+------+----+----+--------------------+--------------------+--------------------+
# |       Loc       | 1522 | 20 | 19 | 0.9870298313878081 | 0.9876703439325114 | 0.9873499837820305 |
# |       Org       | 774  | 13 | 12 | 0.9834815756035579 | 0.9847328244274809 | 0.9841068022886205 |
# |      Other      | 550  | 21 | 23 | 0.9632224168126094 | 0.9598603839441536 | 0.9615384615384615 |
# |       Peop      | 1359 | 11 | 11 | 0.9919708029197081 | 0.9919708029197081 | 0.9919708029197081 |
# |        -        |  -   | -  | -  |         -          |         -          |         -          |
# | Micro NER chunk | 4205 | 65 | 65 | 0.9847775175644028 | 0.9847775175644028 | 0.9847775175644028 |
# +-----------------+------+----+----+--------------------+--------------------+--------------------+
# +-----------------+------+----+----+--------------------+--------------------+--------------------+
# |      Class      |  TP  | FP | FN |         Pr         |         Re         |         F1         |
# +-----------------+------+----+----+--------------------+--------------------+--------------------+
# |       Kill      | 216  | 7  | 5  | 0.968609865470852  | 0.9773755656108597 | 0.972972972972973  |
# |     Live_In     | 403  | 16 | 18 | 0.9618138424821002 | 0.9572446555819477 | 0.9595238095238094 |
# |    Located_In   | 299  | 11 | 13 | 0.964516129032258  | 0.9583333333333334 | 0.9614147909967845 |
# |   OrgBased_In   | 331  | 17 | 16 | 0.9511494252873564 | 0.9538904899135446 | 0.9525179856115108 |
# |     Work_For    | 313  | 12 | 12 | 0.963076923076923  | 0.963076923076923  | 0.963076923076923  |
# |        -        |  -   | -  | -  |         -          |         -          |         -          |
# | Micro REL chunk | 1562 | 63 | 64 | 0.9612307692307692 | 0.9606396063960639 | 0.9609350968932635 |
# +-----------------+------+----+----+--------------------+--------------------+--------------------+
# Elapsed train time in sec:86.00478768348694
#
# -------Evaluate on test-------
# +-----------------+-----+-----+-----+--------------------+--------------------+--------------------+
# |      Class      |  TP |  FP |  FN |         Pr         |         Re         |         F1         |
# +-----------------+-----+-----+-----+--------------------+--------------------+--------------------+
# |       Loc       | 387 |  68 |  40 | 0.8505494505494505 | 0.9063231850117096 | 0.8775510204081632 |
# |       Org       | 149 |  41 |  49 | 0.7842105263157895 | 0.7525252525252525 | 0.768041237113402  |
# |      Other      |  87 |  49 |  46 | 0.6397058823529411 | 0.6541353383458647 | 0.6468401486988846 |
# |       Peop      | 294 |  39 |  27 | 0.8828828828828829 | 0.9158878504672897 | 0.8990825688073394 |
# |        -        |  -  |  -  |  -  |         -          |         -          |         -          |
# | Micro NER chunk | 917 | 197 | 162 | 0.8231597845601436 | 0.8498609823911029 | 0.836297309621523  |
# +-----------------+-----+-----+-----+--------------------+--------------------+--------------------+
# +-----------------+-----+-----+-----+--------------------+---------------------+---------------------+
# |      Class      |  TP |  FP |  FN |         Pr         |          Re         |          F1         |
# +-----------------+-----+-----+-----+--------------------+---------------------+---------------------+
# |       Kill      |  38 |  10 |  9  | 0.7916666666666666 |  0.8085106382978723 |  0.7999999999999999 |
# |     Live_In     |  48 |  33 |  52 | 0.5925925925925926 |         0.48        |  0.5303867403314917 |
# |    Located_In   |  41 |  32 |  53 | 0.5616438356164384 | 0.43617021276595747 | 0.49101796407185627 |
# |   OrgBased_In   |  54 |  17 |  51 | 0.7605633802816901 |  0.5142857142857142 |  0.6136363636363636 |
# |     Work_For    |  38 |  33 |  38 | 0.5352112676056338 |         0.5         |  0.5170068027210885 |
# |        -        |  -  |  -  |  -  |         -          |          -          |          -          |
# | Micro REL chunk | 219 | 125 | 203 | 0.6366279069767442 |  0.518957345971564  |  0.5718015665796344 |
# +-----------------+-----+-----+-----+--------------------+---------------------+---------------------+
#
# - Test score 0.7040494381005787 in 150 epoch
