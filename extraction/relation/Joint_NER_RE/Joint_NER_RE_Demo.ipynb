# %% [markdown]
# %cd '/content/drive/My Drive/temp'

# %%
# !git clone https://github.com/Sanjithae/Joint_NER_RE.git
# Out:
# Cloning into 'Joint_NER_RE'...
# remote: Enumerating objects: 45, done.
# remote: Counting objects: 100% (45/45), done.
# remote: Compressing objects: 100% (44/44), done.
# remote: Total 158 (delta 19), reused 0 (delta 0), pack-reused 113
# Receiving objects: 100% (158/158), 2.72 MiB | 8.25 MiB/s, done.
# Resolving deltas: 100% (50/50), done.

# %%
import nltk
nltk.download('averaged_perceptron_tagger')
# Out:
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Unzipping taggers/averaged_perceptron_tagger.zip.
# True

# %%
# !python main.py
# Out:
# Archive:  data/CoNLL04/vecs.lc.over100freq.zip
#   inflating: data/CoNLL04/vecs.lc.over100freq.txt
# /usr/local/lib/python3.6/dist-packages/smart_open/ssh.py:34: UserWarning: paramiko missing, opening SSH/SCP/SFTP paths will be disabled.  `pip install paramiko` to suppress
#   warnings.warn('paramiko missing, opening SSH/SCP/SFTP paths will be disabled.  `pip install paramiko` to suppress')
# /content/drive/My Drive/temp/Joint_NER_RE/parsers.py:68: FutureWarning: Method .as_matrix will be removed in a future version. Use .values instead.
#   engine='python', sep="\t", quoting=csv.QUOTE_NONE).as_matrix()
# +------------------------+--------------------------------------+
# |         Params         |                Value                 |
# +------------------------+--------------------------------------+
# |         Config         |     ./configs/CoNLL04/bio_config     |
# |       Embeddings       | data/CoNLL04/vecs.lc.over100freq.txt |
# ...
