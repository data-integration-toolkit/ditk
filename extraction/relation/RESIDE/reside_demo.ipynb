# %%
# %run -i reside1.py -name pretrained_model -restore -only_eval
# Out:
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/smart_open/ssh.py:34: UserWarning: paramiko missing, opening SSH/SCP/SFTP paths will be disabled.  `pip install paramiko` to suppress
#   warnings.warn('paramiko missing, opening SSH/SCP/SFTP paths will be disabled.  `pip install paramiko` to suppress')
# 2019-05-01 03:41:44,610 - [INFO] - {'gpu': '0', 'wGate': True, 'lstm_dim': 192, 'pos_dim': 16, 'type_dim': 50, 'alias_dim': 32, 'de_gcn_dim': 16, 'de_layers': 1, 'dropout': 0.8, 'rec_dropout': 0.8, 'lr': 0.001, 'l2': 0.001, 'max_epochs': 2, 'batch_size': 32, 'chunk_size': 1000, 'restore': True, 'only_eval': True, 'opt': 'adam', 'eps': 1e-08, 'name': 'pretrained_model', 'seed': 1234, 'log_dir': './log/', 'config_dir': './config/', 'embed_loc': './glove/glove.6B.50d_word2vec.txt', 'embed_dim': 50}
# {'alias_dim': 32,
#  'batch_size': 32,
#  'chunk_size': 1000,
#  'config_dir': './config/',
#  'de_gcn_dim': 16,
#  'de_layers': 1,
#  'dropout': 0.8,
# ...
