# %% [markdown]
# # RIDDLE for Data Imputation

# %% [markdown]
# ## Setup
#
# <pre><code>% pip install -r requirements.txt
# % apt-get install libhdf5-serial-dev
# </code></pre>
#
# <p><strong>Python Libraries:</strong></p>
# <ul>
# <li>Keras (<code>keras</code>)</li>
# <li>DeepLIFT (<code>deeplift</code>, available on GitHub)</li>
# <li>TensorFlow (<code>tensorflow</code>) or Theano (<code>theano</code>)</li>
# <li>scikit-learn (<code>sklearn</code>)</li>
# <li>NumPy (<code>numpy</code>)</li>
# <li>SciPy (<code>scipy</code>)</li>
# <li>Matplotlib (<code>matplotlib</code>)</li>
# <li>h5py (<code>h5py</code>)</li>
# </ul>
# <p>General:</p>
# <ul>
# <li>HDF5</li>
# </ul>

# %% [markdown]
# ## Training phase
#
# We are trying to tune the parameters in this step and find the best parameters.

# %%
# !python3.6 parameter_search.py
# Out:
# Using TensorFlow backend.
# Loading data...
# Data loaded in 0.39698 s
#
# ------------------------------------------------------------------------
# Partition k = 0
# WARNING:tensorflow:From /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/tensorflow/python/framework/op_def_library.py:263: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# WARNING:tensorflow:From /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py:3445: calling dropout (from tensorflow.python.ops.nn_ops) with keep_prob is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `rate` instead of `keep_prob`. Rate should be set to `rate = 1 - keep_prob`.
# ...

# %% [markdown]
# ### Train and evaluate
# We run the RIDDLE pipeline on the dataset to train and evaluate.

# %%
# !python3.6 riddle.py
# Out:
# Using TensorFlow backend.
# Loading data...
# Data loaded in 0.43161 s
#
# Partition k = 0
#
# WARNING:tensorflow:From /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/tensorflow/python/framework/op_def_library.py:263: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# WARNING:tensorflow:From /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py:3445: calling dropout (from tensorflow.python.ops.nn_ops) with keep_prob is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `rate` instead of `keep_prob`. Rate should be set to `rate = 1 - keep_prob`.
#
#  Epoch 1 start:
# 64 train batches
# -- train batch 0
# ...

# %% [markdown]
# ### Evaluate on Benchmarks

# %% [markdown]
# #### The Breast Cancer Dataset from UCI
#
# Mean Squared Error: 0.4035

# %%
# !python3.6 test_bc.py
# Out:
# Using TensorFlow backend.
# Randomly deleted 3414 feature occurrences
# WARNING:tensorflow:From /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/tensorflow/python/framework/op_def_library.py:263: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# WARNING:tensorflow:From /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py:3445: calling dropout (from tensorflow.python.ops.nn_ops) with keep_prob is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `rate` instead of `keep_prob`. Rate should be set to `rate = 1 - keep_prob`.
#
#  Epoch 1 start:
# 4 train batches
# -- train batch 0
# ...

# %% [markdown]
# #### The Spam Dataset from UCI
# Mean Squared Error: 0.3880

# %%
# !python3.6 test_spam.py
# Out:
# Using TensorFlow backend.
# WARNING:tensorflow:From /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/tensorflow/python/framework/op_def_library.py:263: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# WARNING:tensorflow:From /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py:3445: calling dropout (from tensorflow.python.ops.nn_ops) with keep_prob is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `rate` instead of `keep_prob`. Rate should be set to `rate = 1 - keep_prob`.
#
#  Epoch 1 start:
# 23 train batches
# -- train batch 0
# ...

# %% [markdown]
# #### The Letter Recognition Dataset from UCI
# Mean Squared Error: 106.3980

# %%
# !python3.6 test_letter.py
# Out:
# Using TensorFlow backend.
# test_letter.py:15: ParserWarning: Both a converter and dtype were specified for column letter - only the converter will be used
#   converters= {0: lambda ch: ord(ch)-ord('A')})
# Randomly deleted 64000 feature occurrences
# WARNING:tensorflow:From /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/tensorflow/python/framework/op_def_library.py:263: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# WARNING:tensorflow:From /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py:3445: calling dropout (from tensorflow.python.ops.nn_ops) with keep_prob is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `rate` instead of `keep_prob`. Rate should be set to `rate = 1 - keep_prob`.
#
#  Epoch 1 start:
# ...
